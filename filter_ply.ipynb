# %% [markdown]
# File này: Với các điểm 3D được chuyển đổi trong ROI (output của file project_to_3d), dựa vào output này,
# ta nhìn vào ảnh point cloud để giữ lại các điểm trong ROI.

# %% [markdown]
# Hàm phía dưới là để xử lý với 1 ảnh

# %%
# Ý tưởng:
# 1 Load scene point cloud .ply
# 2 load ROI point cloud (Xyz)
# 3 với mỗi điểm ROI -> tìm điểm gần nhất trong scene (KDTree Search)
# 4 Giữ các điểm trong scene thuộc ROI

# filter_ply.py

import numpy as np
import open3d as o3d

class PointCloudFilter:
    def __init__(self, distance_threshold=0.01):
        """
        @param distance_threshold: Ngưỡng để xác định điểm nào thuộc ROI (m)
        """
        self.distance_threshold = distance_threshold

        # ===== Extrinsics (Camera -> World) =====
        self.R = np.array([
            [0.9999898076057434, -0.00020347206736914814, -0.004507721401751041],
            [0.00018898719281423837, 0.9999948143959045, -0.0032135415822267532],
            [0.004508351907134056, 0.003212657058611512, 0.9999846816062927]
        ])
        self.T = np.array([-0.05905, 8.67399e-05, 0.00041])

        # Tạo extrinsic matrix 4x4
        self.extrinsic = np.eye(4)
        self.extrinsic[:3, :3] = self.R
        self.extrinsic[:3, 3] = self.T

        # ===== Flip Matrix (World -> PLY Coordinate) =====
        self.flip_mat = np.array([
            [1,  0,  0],
            [0, -1,  0],
            [0,  0, -1]
        ])

    def align_roi_to_scene(self, roi_pcd):
        """
        Áp dụng Extrinsic + Flip để đưa ROI vào hệ tọa độ của Scene PLY.
        """
        roi_points = np.asarray(roi_pcd.points)
        roi_points_h = np.hstack((roi_points, np.ones((roi_points.shape[0], 1))))
        
        # Extrinsic transform
        roi_world = (self.extrinsic @ roi_points_h.T).T[:, :3]

        # Flip to PLY coordinate
        roi_aligned = (self.flip_mat @ roi_world.T).T

        roi_pcd.points = o3d.utility.Vector3dVector(roi_aligned)
        return roi_pcd

    def filter_scene_with_roi(self, scene_ply_path, roi_pcd):
        """
        @param scene_ply_path: đường dẫn file PLY đầy đủ
        @param roi_pcd: Open3D ROI PointCloud (chưa transform)
        @return: filtered_point_cloud (Open3D)
        """
        print("🔍 Đọc Scene PLY...")
        scene = o3d.io.read_point_cloud(scene_ply_path)

        print(f"📌 Scene Points: {len(scene.points)}")
        print(f"📌 ROI Points (trước align): {len(roi_pcd.points)}")

        # ===== Chuyển ROI sang hệ tọa độ Scene =====
        roi_pcd = self.align_roi_to_scene(roi_pcd)
        print(f"✅ ROI Points (sau align): {len(roi_pcd.points)}")

        # KDTree cho Scene (tăng tốc độ tìm kiếm)
        kdtree = o3d.geometry.KDTreeFlann(scene)

        scene_points = np.asarray(scene.points)
        keep_mask = np.zeros(len(scene_points), dtype=bool)
        roi_points = np.asarray(roi_pcd.points)

        print("⏳ Đang lọc Scene theo ROI...")

        for roi_pt in roi_points:
            _, idx, dist = kdtree.search_knn_vector_3d(roi_pt, 1)
            if len(idx) > 0 and dist[0] < self.distance_threshold ** 2:
                keep_mask[idx[0]] = True

        filtered_scene = scene.select_by_index(np.where(keep_mask)[0])
        print(f"🎯 Filtered Points: {len(filtered_scene.points)}")

        if len(filtered_scene.points) == 0:
            print("⚠️ Không tìm được điểm nào thuộc ROI trong Scene!")

        # Lưu kết quả
        o3d.io.write_point_cloud("filtered_roi.ply", filtered_scene)
        print("💾 Đã lưu: filtered_roi.ply")

        return filtered_scene

# %% [markdown]
# Test thử với 1 ảnh

# %%
# scene_path = "Public data/Public data train/ply/0002.ply"
# roi_path = "output/filtered_roi_0002.ply"

# roi = o3d.io.read_point_cloud(roi_path)
# filterer = PointCloudFilter(distance_threshold=0.01)

# filtered = filterer.filter_scene_with_roi(scene_path, roi)
# o3d.io.write_point_cloud("output/filtered_scene_0002.ply", filtered)

# print("✅ Filtered PLY saved: output/filtered_scene_0002.ply")

# %%
scene_path = "./Public data/Public data train/ply/0018.ply"
roi_path = "./data/roi_pointclouds/0002.ply"
roi_pcd = o3d.io.read_point_cloud(roi_path)  # ROI từ depth

pcf = PointCloudFilter(distance_threshold=0.01)
filtered = pcf.filter_scene_with_roi(scene_path, roi_pcd)

o3d.visualization.draw_geometries([filtered])
# Out:
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675992
# 📌 ROI Points (trước align): 95860
# ✅ ROI Points (sau align): 95860
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 24791
# 💾 Đã lưu: filtered_roi.ply

# %% [markdown]
# Xử lý trên cả tập data

# %%
import os

# %%
# 1. Cấu hình
scene_folder = "D:/AI_project/VAR/Public data/Public data train/ply"       # thư mục chứa các file scene PLY
roi_folder = "./data/roi_pointclouds"          # file ROI PCD
output_folder = "./data/filtered_ply"    # thư mục lưu kết quả
distance_threshold = 0.01

os.makedirs(output_folder, exist_ok=True)


# 3. Tạo object filter
pc_filter = PointCloudFilter(distance_threshold)

# 4. Lặp qua tất cả file PLY trong thư mục
for filename in os.listdir(scene_folder):
    if not filename.endswith(".ply"):
        continue

    scene_path = os.path.join(scene_folder, filename)
    roi_path = os.path.join(roi_folder, filename)

    print(f"\nĐang xử lý: {filename}")
    print(f"Scene path: {scene_path}")
    print(f"ROI path:   {roi_path}")

    if not os.path.exists(scene_path):
        print("Không tìm thấy scene file, bỏ qua.")
        continue
    if not os.path.exists(roi_path):
        print("Không tìm thấy ROI file, bỏ qua.")
        continue

    roi_pcd = o3d.io.read_point_cloud(roi_path)
    if roi_pcd is None or len(roi_pcd.points) == 0:
        print("Không đọc được hoặc ROI rỗng.")
        continue

    filtered_scene = pc_filter.filter_scene_with_roi(scene_path, roi_pcd)

    if filtered_scene is None or len(filtered_scene.points) == 0:
        print("Không có điểm hợp lệ, bỏ qua.")

    output_path = os.path.join(output_folder, filename)
    success = o3d.io.write_point_cloud(output_path, filtered_scene)
    print("Kết quả lưu:", "Thành công" if success else "Thất bại")
# Out:
# Đang xử lý: 0000.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0000.ply
# ROI path:   ./data/roi_pointclouds\0000.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 681218
# 📌 ROI Points (trước align): 96159
# ✅ ROI Points (sau align): 96159
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 25534
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0001.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0001.ply
# ROI path:   ./data/roi_pointclouds\0001.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 679692
# 📌 ROI Points (trước align): 95676
# ✅ ROI Points (sau align): 95676
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 23511
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0002.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0002.ply
# ROI path:   ./data/roi_pointclouds\0002.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 684068
# 📌 ROI Points (trước align): 95860
# ✅ ROI Points (sau align): 95860
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 24526
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0003.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0003.ply
# ROI path:   ./data/roi_pointclouds\0003.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 678001
# 📌 ROI Points (trước align): 93960
# ✅ ROI Points (sau align): 93960
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 24972
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0004.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0004.ply
# ROI path:   ./data/roi_pointclouds\0004.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 680658
# 📌 ROI Points (trước align): 93939
# ✅ ROI Points (sau align): 93939
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 8042
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0005.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0005.ply
# ROI path:   ./data/roi_pointclouds\0005.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 677057
# 📌 ROI Points (trước align): 95645
# ✅ ROI Points (sau align): 95645
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 30017
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0006.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0006.ply
# ROI path:   ./data/roi_pointclouds\0006.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 671847
# 📌 ROI Points (trước align): 94144
# ✅ ROI Points (sau align): 94144
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 23227
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0007.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0007.ply
# ROI path:   ./data/roi_pointclouds\0007.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674833
# 📌 ROI Points (trước align): 95232
# ✅ ROI Points (sau align): 95232
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 25932
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0008.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0008.ply
# ROI path:   ./data/roi_pointclouds\0008.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674087
# 📌 ROI Points (trước align): 94183
# ✅ ROI Points (sau align): 94183
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 17896
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0009.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0009.ply
# ROI path:   ./data/roi_pointclouds\0009.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674357
# 📌 ROI Points (trước align): 93789
# ✅ ROI Points (sau align): 93789
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 17960
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0010.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0010.ply
# ROI path:   ./data/roi_pointclouds\0010.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675708
# 📌 ROI Points (trước align): 95258
# ✅ ROI Points (sau align): 95258
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 19028
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0011.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0011.ply
# ROI path:   ./data/roi_pointclouds\0011.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 672593
# 📌 ROI Points (trước align): 94755
# ✅ ROI Points (sau align): 94755
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 26975
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0012.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0012.ply
# ROI path:   ./data/roi_pointclouds\0012.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 677185
# 📌 ROI Points (trước align): 94994
# ✅ ROI Points (sau align): 94994
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 12785
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0013.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0013.ply
# ROI path:   ./data/roi_pointclouds\0013.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676656
# 📌 ROI Points (trước align): 93115
# ✅ ROI Points (sau align): 93115
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 21716
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0014.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0014.ply
# ROI path:   ./data/roi_pointclouds\0014.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674293
# 📌 ROI Points (trước align): 92574
# ✅ ROI Points (sau align): 92574
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 14821
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0015.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0015.ply
# ROI path:   ./data/roi_pointclouds\0015.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 677844
# 📌 ROI Points (trước align): 95199
# ✅ ROI Points (sau align): 95199
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 25978
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0016.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0016.ply
# ROI path:   ./data/roi_pointclouds\0016.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 679112
# 📌 ROI Points (trước align): 96273
# ✅ ROI Points (sau align): 96273
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 16442
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0017.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0017.ply
# ROI path:   ./data/roi_pointclouds\0017.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674330
# 📌 ROI Points (trước align): 93678
# ✅ ROI Points (sau align): 93678
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 18415
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0018.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0018.ply
# ROI path:   ./data/roi_pointclouds\0018.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675992
# 📌 ROI Points (trước align): 96178
# ✅ ROI Points (sau align): 96178
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 26757
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0019.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0019.ply
# ROI path:   ./data/roi_pointclouds\0019.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 679553
# 📌 ROI Points (trước align): 96300
# ✅ ROI Points (sau align): 96300
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 31334
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0020.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0020.ply
# ROI path:   ./data/roi_pointclouds\0020.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674766
# 📌 ROI Points (trước align): 95503
# ✅ ROI Points (sau align): 95503
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 22794
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0021.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0021.ply
# ROI path:   ./data/roi_pointclouds\0021.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 673295
# 📌 ROI Points (trước align): 95048
# ✅ ROI Points (sau align): 95048
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 22667
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0022.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0022.ply
# ROI path:   ./data/roi_pointclouds\0022.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675903
# 📌 ROI Points (trước align): 95894
# ✅ ROI Points (sau align): 95894
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 22476
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0023.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0023.ply
# ROI path:   ./data/roi_pointclouds\0023.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 677808
# 📌 ROI Points (trước align): 96734
# ✅ ROI Points (sau align): 96734
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 30440
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0024.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0024.ply
# ROI path:   ./data/roi_pointclouds\0024.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676407
# 📌 ROI Points (trước align): 94984
# ✅ ROI Points (sau align): 94984
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 16471
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0025.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0025.ply
# ROI path:   ./data/roi_pointclouds\0025.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676229
# 📌 ROI Points (trước align): 96129
# ✅ ROI Points (sau align): 96129
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 28548
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0026.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0026.ply
# ROI path:   ./data/roi_pointclouds\0026.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676527
# 📌 ROI Points (trước align): 96079
# ✅ ROI Points (sau align): 96079
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 13904
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0027.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0027.ply
# ROI path:   ./data/roi_pointclouds\0027.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674691
# 📌 ROI Points (trước align): 95779
# ✅ ROI Points (sau align): 95779
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 29360
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0028.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0028.ply
# ROI path:   ./data/roi_pointclouds\0028.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675352
# 📌 ROI Points (trước align): 94150
# ✅ ROI Points (sau align): 94150
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 17009
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0029.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0029.ply
# ROI path:   ./data/roi_pointclouds\0029.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675792
# 📌 ROI Points (trước align): 95463
# ✅ ROI Points (sau align): 95463
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 25320
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0030.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0030.ply
# ROI path:   ./data/roi_pointclouds\0030.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674572
# 📌 ROI Points (trước align): 95025
# ✅ ROI Points (sau align): 95025
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 34154
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0031.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0031.ply
# ROI path:   ./data/roi_pointclouds\0031.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676623
# 📌 ROI Points (trước align): 95179
# ✅ ROI Points (sau align): 95179
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 32260
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0032.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0032.ply
# ROI path:   ./data/roi_pointclouds\0032.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676704
# 📌 ROI Points (trước align): 96344
# ✅ ROI Points (sau align): 96344
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 33835
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0033.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0033.ply
# ROI path:   ./data/roi_pointclouds\0033.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 677492
# 📌 ROI Points (trước align): 93727
# ✅ ROI Points (sau align): 93727
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 18086
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0034.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0034.ply
# ROI path:   ./data/roi_pointclouds\0034.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 679154
# 📌 ROI Points (trước align): 96133
# ✅ ROI Points (sau align): 96133
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 19413
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0035.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0035.ply
# ROI path:   ./data/roi_pointclouds\0035.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674699
# 📌 ROI Points (trước align): 93356
# ✅ ROI Points (sau align): 93356
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 17321
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0036.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0036.ply
# ROI path:   ./data/roi_pointclouds\0036.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674659
# 📌 ROI Points (trước align): 94394
# ✅ ROI Points (sau align): 94394
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 9864
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0037.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0037.ply
# ROI path:   ./data/roi_pointclouds\0037.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674115
# 📌 ROI Points (trước align): 95328
# ✅ ROI Points (sau align): 95328
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 15068
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0038.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0038.ply
# ROI path:   ./data/roi_pointclouds\0038.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 677748
# 📌 ROI Points (trước align): 94443
# ✅ ROI Points (sau align): 94443
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 16887
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0039.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0039.ply
# ROI path:   ./data/roi_pointclouds\0039.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675872
# 📌 ROI Points (trước align): 96422
# ✅ ROI Points (sau align): 96422
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 35347
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0040.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0040.ply
# ROI path:   ./data/roi_pointclouds\0040.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676743
# 📌 ROI Points (trước align): 95923
# ✅ ROI Points (sau align): 95923
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 31533
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0041.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0041.ply
# ROI path:   ./data/roi_pointclouds\0041.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674949
# 📌 ROI Points (trước align): 95815
# ✅ ROI Points (sau align): 95815
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 27513
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0042.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0042.ply
# ROI path:   ./data/roi_pointclouds\0042.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674018
# 📌 ROI Points (trước align): 94633
# ✅ ROI Points (sau align): 94633
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 15325
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0043.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0043.ply
# ROI path:   ./data/roi_pointclouds\0043.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 672397
# 📌 ROI Points (trước align): 92546
# ✅ ROI Points (sau align): 92546
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 11733
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0044.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0044.ply
# ROI path:   ./data/roi_pointclouds\0044.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 674733
# 📌 ROI Points (trước align): 96742
# ✅ ROI Points (sau align): 96742
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 34107
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0045.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0045.ply
# ROI path:   ./data/roi_pointclouds\0045.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676859
# 📌 ROI Points (trước align): 94834
# ✅ ROI Points (sau align): 94834
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 10469
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0046.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0046.ply
# ROI path:   ./data/roi_pointclouds\0046.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 677619
# 📌 ROI Points (trước align): 95797
# ✅ ROI Points (sau align): 95797
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 23455
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0047.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0047.ply
# ROI path:   ./data/roi_pointclouds\0047.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 676771
# 📌 ROI Points (trước align): 96033
# ✅ ROI Points (sau align): 96033
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 10943
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0048.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0048.ply
# ROI path:   ./data/roi_pointclouds\0048.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 675387
# 📌 ROI Points (trước align): 96287
# ✅ ROI Points (sau align): 96287
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 31790
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công
#
# Đang xử lý: 0049.ply
# Scene path: D:/AI_project/VAR/Public data/Public data train/ply\0049.ply
# ROI path:   ./data/roi_pointclouds\0049.ply
# 🔍 Đọc Scene PLY...
# 📌 Scene Points: 679506
# 📌 ROI Points (trước align): 96005
# ✅ ROI Points (sau align): 96005
# ⏳ Đang lọc Scene theo ROI...
# 🎯 Filtered Points: 20639
# 💾 Đã lưu: filtered_roi.ply
# Kết quả lưu: Thành công

# %% [markdown]
# Xem ảnh

# %%
pc = o3d.io.read_point_cloud("D:/AI_project/VAR/data/filtered_ply/0048.ply")
print(pc)
o3d.visualization.draw_geometries([pc])
# Out:
# PointCloud with 31790 points.

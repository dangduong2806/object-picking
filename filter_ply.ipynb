# %% [markdown]
# File này: Với các điểm 3D được chuyển đổi trong ROI (output của file project_to_3d), dựa vào output này,
# ta nhìn vào ảnh point cloud để giữ lại các điểm trong ROI.

# %% [markdown]
# Hàm phía dưới là để xử lý với 1 ảnh

# %%
# Ý tưởng:
# 1 Load scene point cloud .ply
# 2 load ROI point cloud (Xyz)
# 3 với mỗi điểm ROI -> tìm điểm gần nhất trong scene (KDTree Search)
# 4 Giữ các điểm trong scene thuộc ROI

# filter_ply.py

import numpy as np
import open3d as o3d

class PointCloudFilter:
    def __init__(self, distance_threshold=0.01):
        """
        @param distance_threshold: Ngưỡng để xác định điểm nào thuộc ROI (m)
        """
        self.distance_threshold = distance_threshold

    def filter_scene_with_roi(self, scene_ply_path, roi_pcd):
        """
        @param scene_ply_path: đường dẫn file PLY đầy đủ
        @param roi_pcd: Open3D ROI PointCloud
        @return: filtered_point_cloud (Open3D)
        """
        scene = o3d.io.read_point_cloud(scene_ply_path)

        # KDTree cho scene (tăng tốc độ tìm kiếm lân cận)
        kdtree = o3d.geometry.KDTreeFlann(scene)

        scene_points = np.asarray(scene.points)
        keep_mask = np.zeros(len(scene_points), dtype=bool)

        roi_points = np.asarray(roi_pcd.points)

        for roi_pt in roi_points:
            _, idx, dist = kdtree.search_knn_vector_3d(roi_pt, 1)
            if len(idx) > 0 and dist[0] < self.distance_threshold ** 2:
                [k, idx, dist] = kdtree.search_radius_vector_3d(roi_pt, self.distance_threshold)
                keep_mask[idx] = True

        filtered_scene = scene.select_by_index(np.where(keep_mask)[0])
        return filtered_scene
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# Test thử với 1 ảnh

# %%
# scene_path = "Public data/Public data train/ply/0002.ply"
# roi_path = "output/filtered_roi_0002.ply"

# roi = o3d.io.read_point_cloud(roi_path)
# filterer = PointCloudFilter(distance_threshold=0.01)

# filtered = filterer.filter_scene_with_roi(scene_path, roi)
# o3d.io.write_point_cloud("output/filtered_scene_0002.ply", filtered)

# print("✅ Filtered PLY saved: output/filtered_scene_0002.ply")

# %% [markdown]
# Xử lý trên cả tập data

# %%
import os

# %%
# 1. Cấu hình
scene_folder = "./Public_data_task_3/Public_data/Public_data_train/ply"       # thư mục chứa các file scene PLY
roi_folder = "./data/roi_pointclouds"          # file ROI PCD
output_folder = "./data/filtered_ply"    # thư mục lưu kết quả
distance_threshold = 0.01

os.makedirs(output_folder, exist_ok=True)

# 2. Load ROI once
# roi_pcd = o3d.io.read_point_cloud(roi_file)

# 3. Tạo object filter
pc_filter = PointCloudFilter(distance_threshold)

# 4. Lặp qua tất cả file PLY trong thư mục
for filename in os.listdir(scene_folder):
    if not filename.endswith(".ply"):
        continue

    scene_path = os.path.join(scene_folder, filename)
    roi_path = os.path.join(roi_folder, filename)

    print(f"\nĐang xử lý: {filename}")
    print(f"Scene path: {scene_path}")
    print(f"ROI path:   {roi_path}")

    if not os.path.exists(scene_path):
        print("Không tìm thấy scene file, bỏ qua.")
        continue
    if not os.path.exists(roi_path):
        print("Không tìm thấy ROI file, bỏ qua.")
        continue

    roi_pcd = o3d.io.read_point_cloud(roi_path)
    if roi_pcd is None or len(roi_pcd.points) == 0:
        print("Không đọc được hoặc ROI rỗng.")
        continue

    filtered_scene = pc_filter.filter_scene_with_roi(scene_path, roi_pcd)

    if filtered_scene is None or len(filtered_scene.points) == 0:
        print("Không có điểm hợp lệ, bỏ qua.")

    output_path = os.path.join(output_folder, filename)
    success = o3d.io.write_point_cloud(output_path, filtered_scene)
    print("Kết quả lưu:", "Thành công" if success else "Thất bại")
# Out:
# Đang xử lý: 0000.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0000.ply
# ROI path:   ./data/roi_pointclouds\0000.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0001.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0001.ply
# ROI path:   ./data/roi_pointclouds\0001.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0002.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0002.ply
# ROI path:   ./data/roi_pointclouds\0002.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0003.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0003.ply
# ROI path:   ./data/roi_pointclouds\0003.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0004.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0004.ply
# ROI path:   ./data/roi_pointclouds\0004.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0005.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0005.ply
# ROI path:   ./data/roi_pointclouds\0005.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0006.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0006.ply
# ROI path:   ./data/roi_pointclouds\0006.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0007.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0007.ply
# ROI path:   ./data/roi_pointclouds\0007.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0008.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0008.ply
# ROI path:   ./data/roi_pointclouds\0008.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0009.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0009.ply
# ROI path:   ./data/roi_pointclouds\0009.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0010.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0010.ply
# ROI path:   ./data/roi_pointclouds\0010.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0011.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0011.ply
# ROI path:   ./data/roi_pointclouds\0011.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0012.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0012.ply
# ROI path:   ./data/roi_pointclouds\0012.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0013.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0013.ply
# ROI path:   ./data/roi_pointclouds\0013.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0014.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0014.ply
# ROI path:   ./data/roi_pointclouds\0014.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0015.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0015.ply
# ROI path:   ./data/roi_pointclouds\0015.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0016.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0016.ply
# ROI path:   ./data/roi_pointclouds\0016.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0017.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0017.ply
# ROI path:   ./data/roi_pointclouds\0017.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0018.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0018.ply
# ROI path:   ./data/roi_pointclouds\0018.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0019.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0019.ply
# ROI path:   ./data/roi_pointclouds\0019.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0020.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0020.ply
# ROI path:   ./data/roi_pointclouds\0020.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0021.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0021.ply
# ROI path:   ./data/roi_pointclouds\0021.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0022.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0022.ply
# ROI path:   ./data/roi_pointclouds\0022.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0023.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0023.ply
# ROI path:   ./data/roi_pointclouds\0023.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0024.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0024.ply
# ROI path:   ./data/roi_pointclouds\0024.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0025.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0025.ply
# ROI path:   ./data/roi_pointclouds\0025.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0026.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0026.ply
# ROI path:   ./data/roi_pointclouds\0026.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0027.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0027.ply
# ROI path:   ./data/roi_pointclouds\0027.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0028.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0028.ply
# ROI path:   ./data/roi_pointclouds\0028.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0029.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0029.ply
# ROI path:   ./data/roi_pointclouds\0029.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0030.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0030.ply
# ROI path:   ./data/roi_pointclouds\0030.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0031.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0031.ply
# ROI path:   ./data/roi_pointclouds\0031.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0032.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0032.ply
# ROI path:   ./data/roi_pointclouds\0032.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0033.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0033.ply
# ROI path:   ./data/roi_pointclouds\0033.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0034.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0034.ply
# ROI path:   ./data/roi_pointclouds\0034.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0035.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0035.ply
# ROI path:   ./data/roi_pointclouds\0035.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0036.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0036.ply
# ROI path:   ./data/roi_pointclouds\0036.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0037.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0037.ply
# ROI path:   ./data/roi_pointclouds\0037.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0038.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0038.ply
# ROI path:   ./data/roi_pointclouds\0038.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0039.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0039.ply
# ROI path:   ./data/roi_pointclouds\0039.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0040.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0040.ply
# ROI path:   ./data/roi_pointclouds\0040.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0041.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0041.ply
# ROI path:   ./data/roi_pointclouds\0041.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0042.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0042.ply
# ROI path:   ./data/roi_pointclouds\0042.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0043.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0043.ply
# ROI path:   ./data/roi_pointclouds\0043.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0044.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0044.ply
# ROI path:   ./data/roi_pointclouds\0044.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0045.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0045.ply
# ROI path:   ./data/roi_pointclouds\0045.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0046.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0046.ply
# ROI path:   ./data/roi_pointclouds\0046.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0047.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0047.ply
# ROI path:   ./data/roi_pointclouds\0047.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0048.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0048.ply
# ROI path:   ./data/roi_pointclouds\0048.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
#
# Đang xử lý: 0049.ply
# Scene path: ./Public_data_task_3/Public_data/Public_data_train/ply\0049.ply
# ROI path:   ./data/roi_pointclouds\0049.ply
# Không có điểm hợp lệ, bỏ qua.
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.
# Kết quả lưu: Thất bại
